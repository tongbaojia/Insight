# %%
import urllib.request
import shutil
from tqdm import tqdm

# for i in tqdm(range(1, 61)):
#     url = "http://down010701.tingclass.net/lesson/shi0529/0000/45/" + str(i) + ".mp3"
#     output_file = str(i) + ".mp3"
#     with urllib.request.urlopen(url) as response, open(output_file, 'wb') as out_file:
#         shutil.copyfileobj(response, out_file)

# %%
# !mv ../../../*.mp3 .

# %%
# !ls
# Out:
# 1.TXT
# 1.mp3
# 10.TXT
# 10.mp3
# 11.TXT
# 11.mp3
# 12.TXT
# 12.mp3
# 13.TXT
# 13.mp3
# 14.TXT
# 14.mp3
# 15.TXT
# 15.mp3
# 16.TXT
# 16.mp3
# 17.TXT
# 17.mp3
# 18.TXT
# 18.mp3
# 19.TXT
# 19.mp3
# 2.TXT
# 2.mp3
# 20.TXT
# 20.mp3
# 21.TXT
# 21.mp3
# 22.TXT
# 22.mp3
# 23.TXT
# 23.mp3
# 24.TXT
# 24.mp3
# 25.TXT
# 25.mp3
# 26.TXT
# 26.mp3
# 27.TXT
# 27.mp3
# 28.TXT
# 28.mp3
# 29.TXT
# 29.mp3
# 3.TXT
# 3.mp3
# 30.TXT
# 30.mp3
# 31.TXT
# 31.mp3
# 32.TXT
# 32.mp3
# 33.TXT
# 33.mp3
# 34.TXT
# 34.mp3
# 35.TXT
# 35.mp3
# 36.TXT
# 36.mp3
# 37.TXT
# 37.mp3
# 38.TXT
# 38.mp3
# 39.TXT
# 39.mp3
# 4.TXT
# 4.mp3
# 40.TXT
# 40.mp3
# 41.TXT
# 41.mp3
# 42.TXT
# 42.mp3
# 43.TXT
# 43.mp3
# 44.TXT
# 44.mp3
# 45.TXT
# 45.mp3
# 46.TXT
# 46.mp3
# 47.TXT
# 47.mp3
# 48.TXT
# 48.mp3
# 49.TXT
# 49.mp3
# 5.TXT
# 5.mp3
# 50.TXT
# 50.mp3
# 51.TXT
# 51.mp3
# 52.TXT
# 52.mp3
# 53.TXT
# 53.mp3
# 54.TXT
# 54.mp3
# 55.TXT
# 55.mp3
# 56.TXT
# 56.mp3
# 57.TXT
# 57.mp3
# 58.TXT
# 58.mp3
# 59.TXT
# 59.mp3
# 6.TXT
# 6.mp3
# ...

# %%
from pydub import AudioSegment

for i in tqdm(range(1, 61)):
    sound = AudioSegment.from_mp3(str(i) + ".mp3")
    sound.export(str(i) + ".wav", format="wav")
# Out:
# 100%|██████████| 60/60 [00:14<00:00,  4.06it/s]

# %%
# !ls
# Out:
# 1.TXT
# 1.mp3
# 1.wav
# 10.TXT
# 10.mp3
# 10.wav
# 11.TXT
# 11.mp3
# 11.wav
# 12.TXT
# 12.mp3
# 12.wav
# 13.TXT
# 13.mp3
# 13.wav
# 14.TXT
# 14.mp3
# 14.wav
# 15.TXT
# 15.mp3
# 15.wav
# 16.TXT
# 16.mp3
# 16.wav
# 17.TXT
# 17.mp3
# 17.wav
# 18.TXT
# 18.mp3
# 18.wav
# 19.TXT
# 19.mp3
# 19.wav
# 2.TXT
# 2.mp3
# 2.wav
# 20.TXT
# 20.mp3
# 20.wav
# 21.TXT
# 21.mp3
# 21.wav
# 22.TXT
# 22.mp3
# 22.wav
# 23.TXT
# 23.mp3
# 23.wav
# 24.TXT
# 24.mp3
# 24.wav
# 25.TXT
# 25.mp3
# 25.wav
# 26.TXT
# 26.mp3
# 26.wav
# 27.TXT
# 27.mp3
# 27.wav
# 28.TXT
# 28.mp3
# 28.wav
# 29.TXT
# 29.mp3
# 29.wav
# 3.TXT
# 3.mp3
# 3.wav
# 30.TXT
# 30.mp3
# 30.wav
# 31.TXT
# 31.mp3
# 31.wav
# 32.TXT
# 32.mp3
# 32.wav
# 33.TXT
# 33.mp3
# 33.wav
# 34.TXT
# 34.mp3
# 34.wav
# 35.TXT
# 35.mp3
# 35.wav
# 36.TXT
# 36.mp3
# 36.wav
# 37.TXT
# 37.mp3
# 37.wav
# 38.TXT
# 38.mp3
# 38.wav
# 39.TXT
# 39.mp3
# 39.wav
# 4.TXT
# 4.mp3
# 4.wav
# 40.TXT
# 40.mp3
# 40.wav
# 41.TXT
# 41.mp3
# 41.wav
# 42.TXT
# 42.mp3
# 42.wav
# 43.TXT
# ...
