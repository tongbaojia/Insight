# %%
# !ls
# Out:
# 1.TXT
# 101.TXT
# 103.TXT
# 105.TXT
# 107.TXT
# 109.TXT
# 11.TXT
# 111.TXT
# 113.TXT
# 115.TXT
# 117.TXT
# 119.TXT
# 121.TXT
# 123.TXT
# 125.TXT
# 127.TXT
# 129.TXT
# 13.TXT
# 131.TXT
# 133.TXT
# 135.TXT
# 137.TXT
# 139.TXT
# 141.TXT
# 143.TXT
# 15.TXT
# 17.TXT
# 19.TXT
# 21.TXT
# 23.TXT
# 25.TXT
# 27.TXT
# 29.TXT
# 3.TXT
# 31.TXT
# 33.TXT
# 35.TXT
# 37.TXT
# 39.TXT
# 41.TXT
# 43.TXT
# 45.TXT
# 47.TXT
# 49.TXT
# 5.TXT
# 51.TXT
# 53.TXT
# 55.TXT
# 57.TXT
# 59.TXT
# 61.TXT
# 63.TXT
# 65.TXT
# 67.TXT
# 69.TXT
# 7.TXT
# 71.TXT
# 73.TXT
# 75.TXT
# 77.TXT
# 79.TXT
# 81.TXT
# 83.TXT
# 85.TXT
# 87.TXT
# 89.TXT
# 9.TXT
# 91.TXT
# 93.TXT
# 95.TXT
# 97.TXT
# 99.TXT
# Lesson 1 Excuse me.wav
# Lesson 101 A card from Jimmy.wav
# Lesson 103 The Intelligence test.wav
# Lesson 105Full of mistakes.wav
# Lesson 107 It°Øs too small.wav
# Lesson 109 A good idea.wav
# Lesson 11 Is this your shirt.wav
# Lesson 111 The most expensive model.wav
# Lesson 113 small change.wav
# ...

# %%
import urllib.request
import shutil
from tqdm import tqdm

for i in tqdm(range(1, 145, 2)):
    url = "http://down010701.tingclass.net/lesson/shi0529/0000/43/" + str(i) + ".mp3"
    output_file = str(i) + ".mp3"
    with urllib.request.urlopen(url) as response, open(output_file, 'wb') as out_file:
        shutil.copyfileobj(response, out_file)
# Out:
# 100%|██████████| 72/72 [04:24<00:00,  3.67s/it]

# %%
from pydub import AudioSegment

for i in tqdm(range(1, 145, 2)):
    sound = AudioSegment.from_mp3(str(i) + ".mp3")
    sound.export(str(i) + ".wav", format="wav")
# Out:
# 100%|██████████| 72/72 [00:11<00:00,  6.08it/s]
