# %% [markdown]
# ## Loading Libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = (12.0, 10.0) # set default size of plots
sns.set()
# %matplotlib inline

# %% [markdown]
# ## Import Data

# %%
! ls Data
# Out:
# TempData.csv

# %%
df_raw = pd.read_csv("Data/TempData.csv")
df_raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2716 entries, 0 to 2715
# Data columns (total 39 columns):
# index                    2716 non-null int64
# Unnamed: 0               2716 non-null int64
# alcohol_use              0 non-null float64
# anencephaly              2305 non-null float64
# attendant                2700 non-null object
# birth_loc_type           2319 non-null float64
# birth_month              2716 non-null object
# birth_state              0 non-null float64
# birth_weight             2709 non-null float64
# birth_year               2716 non-null int64
# cigarette_use            0 non-null float64
# cigarettes_per_day       0 non-null float64
# cigarettes_trimester1    2169 non-null float64
# cigarettes_trimester2    2169 non-null float64
# cigarettes_trimester3    2169 non-null float64
# day                      2716 non-null object
# delivery_method          2710 non-null object
# downs syndrome           2305 non-null float64
# drinks_per_week          0 non-null float64
# father_age               0 non-null float64
# father_race              1822 non-null object
# gestation_weeks          2714 non-null float64
# infant_sex               2716 non-null object
# mother_age               2716 non-null int64
# mother_birth_country     0 non-null float64
# mother_birth_state       0 non-null float64
# mother_education         2319 non-null object
# mother_marital_status    2716 non-null object
# mother_race              364 non-null object
# mother_state             0 non-null float64
# population               0 non-null float64
# pregnancy_weight         0 non-null float64
# resident                 2716 non-null object
# revision                 2716 non-null object
# spina_bifida             2305 non-null float64
# table                    2716 non-null object
# timestamp                2716 non-null int64
# uses_tobacco             0 non-null float64
# weight_gain              2583 non-null float64
# dtypes: float64(22), int64(5), object(12)
# memory usage: 827.6+ KB

# %% [markdown]
# ## Clean the missing information

# %%
df_temp = df_raw.dropna(axis=1, how='all')
df_temp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2716 entries, 0 to 2715
# Data columns (total 27 columns):
# index                    2716 non-null int64
# Unnamed: 0               2716 non-null int64
# anencephaly              2305 non-null float64
# attendant                2700 non-null object
# birth_loc_type           2319 non-null float64
# birth_month              2716 non-null object
# birth_weight             2709 non-null float64
# birth_year               2716 non-null int64
# cigarettes_trimester1    2169 non-null float64
# cigarettes_trimester2    2169 non-null float64
# cigarettes_trimester3    2169 non-null float64
# day                      2716 non-null object
# delivery_method          2710 non-null object
# downs syndrome           2305 non-null float64
# father_race              1822 non-null object
# gestation_weeks          2714 non-null float64
# infant_sex               2716 non-null object
# mother_age               2716 non-null int64
# mother_education         2319 non-null object
# mother_marital_status    2716 non-null object
# mother_race              364 non-null object
# resident                 2716 non-null object
# revision                 2716 non-null object
# spina_bifida             2305 non-null float64
# table                    2716 non-null object
# timestamp                2716 non-null int64
# weight_gain              2583 non-null float64
# dtypes: float64(10), int64(5), object(12)
# memory usage: 573.0+ KB

# %%
df = df_temp.dropna(subset=['birth_weight', 'cigarettes_trimester1'], how='any').sample(frac=0.1)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 216 entries, 1487 to 791
# Data columns (total 27 columns):
# index                    216 non-null int64
# Unnamed: 0               216 non-null int64
# anencephaly              215 non-null float64
# attendant                216 non-null object
# birth_loc_type           216 non-null float64
# birth_month              216 non-null object
# birth_weight             216 non-null float64
# birth_year               216 non-null int64
# cigarettes_trimester1    216 non-null float64
# cigarettes_trimester2    216 non-null float64
# cigarettes_trimester3    216 non-null float64
# day                      216 non-null object
# delivery_method          215 non-null object
# downs syndrome           215 non-null float64
# father_race              169 non-null object
# gestation_weeks          216 non-null float64
# infant_sex               216 non-null object
# mother_age               216 non-null int64
# mother_education         216 non-null object
# mother_marital_status    216 non-null object
# mother_race              0 non-null object
# resident                 216 non-null object
# revision                 216 non-null object
# spina_bifida             215 non-null float64
# table                    216 non-null object
# timestamp                216 non-null int64
# weight_gain              208 non-null float64
# dtypes: float64(10), int64(5), object(12)
# memory usage: 47.2+ KB

# %%
df.describe()
# Out:
#              index   Unnamed: 0  anencephaly  birth_loc_type  birth_weight  \
# count   216.000000   216.000000        215.0      216.000000    216.000000
# mean   1375.138889  1375.138889          0.0        1.027778   3909.699074
# std     764.642898   764.642898          0.0        0.234603    913.160511
# min     156.000000   156.000000          0.0        1.000000    500.000000
# 25%     705.750000   705.750000          0.0        1.000000   3000.000000
# 50%    1308.000000  1308.000000          0.0        1.000000   4000.000000
# 75%    2012.000000  2012.000000          0.0        1.000000   4500.000000
# max    2713.000000  2713.000000          0.0        3.000000   8165.000000
#
#        birth_year  cigarettes_trimester1  cigarettes_trimester2  \
# count       216.0             216.000000             216.000000
# mean       2012.0               0.805556               0.689815
# std           0.0               3.239174               2.867798
# min        2012.0               0.000000               0.000000
# 25%        2012.0               0.000000               0.000000
# 50%        2012.0               0.000000               0.000000
# 75%        2012.0               0.000000               0.000000
# max        2012.0              20.000000              20.000000
#
#        cigarettes_trimester3  downs syndrome  gestation_weeks  mother_age  \
# count             216.000000           215.0       216.000000  216.000000
# mean                0.745370             0.0        38.587963   27.870370
# std                 3.127519             0.0         2.009661    6.048013
# min                 0.000000             0.0        31.000000   17.000000
# 25%                 0.000000             0.0        38.000000   23.000000
# 50%                 0.000000             0.0        39.000000   28.000000
# 75%                 0.000000             0.0        40.000000   32.000000
# max                20.000000             0.0        42.000000   43.000000
#
#        spina_bifida     timestamp  weight_gain
# count         215.0  2.160000e+02   208.000000
# mean            0.0  1.340781e+09    30.725962
# std             0.0  9.311289e+06    14.295937
# min             0.0  1.325424e+09     0.000000
# 25%             0.0  1.333232e+09    21.750000
# 50%             0.0  1.340379e+09    31.000000
# 75%             0.0  1.349164e+09    38.250000
# max             0.0  1.357006e+09    77.000000

# %%
plt.clf()
sns.swarmplot(x="birth_weight", y="mother_age", hue="infant_sex", data=df, split=True)
plt.show()
